# %% [markdown]
# # Twitter Stream to Kafka

# %% [markdown]
# ### Import following libaries:

# %%
try: 
    import time
    import tweepy
    from kafka import KafkaProducer, KafkaClient
    
except: 
    print("Import Error!")

# %% [markdown]
# ### Credentials for Twitter API

# %%
# only bearer token needed
API_KEY="k5lkPdbW3yiv6OugISottI1UO"
API_KEY_SECRET="DeHEgtGAQG4gmfYj84147T1h1tmZvG0n6NzvMbGvxYh4J2ENI1"
Bearer_Token="AAAAAAAAAAAAAAAAAAAAAJg0hgEAAAAANc2TTj1gRZmKW2rq8NZvBst3DXA%3DLRNYWs2gQ144fZI9GSDCWY7jZjWY7X6IDbweA395rvScIKbo5V"
Access_Token="3012781875-FobPXdaEUULbVRl7SxgJd6aofifDQ0OvNUJpM3Z"
Access_Token_Secret="6YBex4ApVSAiznUb5CJICHiGAFw5AlVC4rmEHTMPZYOSG"

# %% [markdown]
# ### Functionality and rules for stream

# %%
class TweetStreamV2(tweepy.StreamingClient):
    
    producer = KafkaProducer(bootstrap_servers='localhost:9092', key_serializer=str.encode)
    
    new_tweet = {}
    def on_connect(self):
        print("Connected!")
    def on_includes(self, includes):
        self.new_tweet["username"] = includes["users"][0].username
        print(self.new_tweet)
    def on_tweet(self, tweet):
        if tweet.referenced_tweets == None:
            if "Chicago" in tweet.text:
                self.producer.send("saCity", key="CHI", value=tweet.text.encode('utf-8'))
            if "London" in tweet.text:
                self.producer.send("saCity", key="LON", value=tweet.text.encode('utf-8'))

            time.sleep(0.3)

# %% [markdown]
# ### Run application, streams data to kafka topic

# %%
def main():
    
    query = "Chicago OR London"
    stream = TweetStreamV2(Bearer_Token)

    #add new query
    stream.add_rules(tweepy.StreamRule(query))

    stream.filter(
        tweet_fields=["created_at", "lang"],
        expansions=["author_id"],
        user_fields=["username", "name"],
    )

#RUN
main()
# Out:
# Connected!
# {'username': 'DahliaZef'}
# {'username': 'Lenita14822021'}
# {'username': 'darkie_goldie'}
# {'username': 'F_DombreCoste'}
# {'username': 'margarita_bundi'}
# {'username': 'mikeytull'}
# {'username': 'PMTJames'}
# {'username': 'blkranger12'}
# {'username': 'CryptopianC'}
# {'username': 'ajzxne'}
# {'username': 'NftSunage'}
# {'username': 'Trudilu'}
# {'username': 'corollablunt'}
# {'username': 'JJMMendez30'}
# {'username': 'Waris_Khan00'}
# {'username': 'germantownbttm'}
# {'username': 'Posthistoric19'}
# {'username': 'Awesome_Man20'}
# {'username': 'motherlode182'}
# {'username': 'DadsThumb'}
# {'username': 'DaKingBoba'}
# {'username': 'irobyn'}
# {'username': 'hivoltagephotos'}
# {'username': '1971kpc'}
# {'username': 'LindaHurrell'}
# {'username': 'jamjar1970'}
# {'username': 'andremtl123'}
# {'username': 'Kak_toTak_2019'}
# {'username': 'awfcemily'}
# {'username': 'irobyn'}
# {'username': 'RoySure'}
# {'username': 'anebjamin'}
# {'username': 'Marilyn_huartt'}
# {'username': 'DeeksViewOG'}
# {'username': 'Chondraki'}
# {'username': 'TransTechSocial'}
# {'username': 'GlasnerHelmut'}
# {'username': 'ChicagoWhales1'}
# {'username': 'SaqRaza1'}
# {'username': 'AyMiYaquisita'}
# {'username': 'MahhrabS'}
# {'username': 'ringringdenim'}
# {'username': 'TuSenz'}
# {'username': 'germantownbttm'}
# {'username': 'donvanderveen'}
# {'username': 'itsnot_pink'}
# {'username': 'Hiral_6_12'}
# {'username': 'MatthewACherry'}
# {'username': 'afinity2'}
# {'username': 'apothecaryrose2'}
# {'username': 'ansaAhmed5'}
# {'username': 'ClosedSessions'}
# {'username': 'Gary56384708'}
# {'username': 'inanna_nalytica'}
# {'username': 'IsmaeelDar'}
# {'username': 'TONE1923'}
# {'username': 'Wibbersengland'}
# {'username': 'WhistlerzJoey'}
# {'username': 'sidney_akena'}
# {'username': 'postermankev'}
# {'username': 'nickforIran'}
# {'username': 'UkPropertyLion'}
# {'username': 'ajenglishby'}
# {'username': 'IronEagle861'}
# {'username': 'camfromthe216'}
# {'username': 'LoadingM088'}
# {'username': 'josh__tntl'}
# {'username': 'Claudia56625522'}
# {'username': 'joemartinez1195'}
# {'username': 'ScrumQueens'}
# {'username': 'Bayoir'}
# {'username': 'FezApe_801'}
# {'username': 'telephonisttm'}
# {'username': 'TehmasZohra'}
# {'username': 'allisonsessions'}
# {'username': 'AlpDennis'}
# {'username': 'BarnetPost'}
# {'username': 'Farasatalipak1'}
# {'username': 'KavuncuRomain'}
# {'username': 'Tzahid151'}
# {'username': 'LesleaP'}
# {'username': '1_DrewOG'}
# {'username': 'mediafrendzee'}
# {'username': 'JuttaSandvoss'}
# {'username': 'SuperEbza'}
# {'username': 'LizaAntara2'}
# {'username': 'zia_gul1'}
# {'username': 'aroundthehouses'}
# {'username': 'ivie04aolcom1'}
# {'username': 'nosheensultan1'}
# {'username': 'Rafa2002M'}
# {'username': 'Useroutofreach1'}
# {'username': 'NazaninA1979'}
# {'username': 'PaulaWh51012635'}
# {'username': 'momtoyosi'}
# {'username': 'TheRightAva'}
# {'username': 'TheTouchdownNFL'}
# {'username': 'austenite_m'}
# {'username': 'gary_burr'}
# {'username': 'Zooescape'}
# {'username': 'TalineVazgen'}
# {'username': 'coldfIowers'}
# {'username': 'janelli_perezz'}
# {'username': 'UpandAdamHourly'}
# {'username': 'kikosg08'}
# {'username': 'FckinQuis'}
# {'username': 'Donpmf'}
# {'username': 'germantownbttm'}
# {'username': 'KhyreePoole'}
# {'username': 'JulietKirkwood'}
# {'username': 'rel77texas'}
# {'username': 'Pissoffmate5'}
# {'username': 'bam241264'}
# {'username': 'urbanvirsa82'}
# {'username': 'ZiwaniNairobi'}
# {'username': 'LindaHurrell'}
# {'username': 'VaginasaurusRx'}
# {'username': 'Fariha99753468'}
# {'username': 'merseysidebest'}
# {'username': 'QasimMehdiRaja1'}
# {'username': 'NaeemHaleema'}
# {'username': 'SundayO24605020'}
# {'username': 'ayaelbarhimy'}
# {'username': 'GERMAN85392863'}
# {'username': 'Wattwurm20'}
# {'username': 'Robderbs'}
# {'username': 'frank_h_1969'}
# {'username': 'PhillyPhan513'}
# {'username': 'TheDonnieDarko1'}
# {'username': 'genevegladovn'}
# {'username': 'JanKhan20104863'}
# {'username': 'EDUCATCHER'}
# {'username': 'ayeaye06742785'}
# {'username': 'thesculptress'}
# {'username': 'hollywoodcruz27'}
# {'username': 'kareem_sizebaba'}
# {'username': 'CohibaSmkr'}
# {'username': 'Potters67'}
# {'username': 'pugh_joel'}
# {'username': 'Baig7177'}
# {'username': 'ravensfan562'}
# {'username': 'izelsezer'}
# {'username': 'NiyonkuruRodrg'}
# {'username': 'mike_mcgb'}
# {'username': 'mattyt502'}
# {'username': 'jamesimtoold'}
# {'username': 'FAISALNAUMANBU1'}
# {'username': 'walk_with_wings'}
# {'username': '2STARTHEU'}
# {'username': 'TeaWithEmilia'}
# {'username': 'Mumboejumboh'}
# {'username': 'Andreas_R_Lutz'}
# {'username': 'shedlemon'}
# {'username': 'nero__127'}
# {'username': 'dlbotto'}
# {'username': 'chef_bo_yardee'}
# {'username': 'Perish_Grind'}
# {'username': 'ringringdenim'}
# {'username': 'Angelfoxdreamer'}
# {'username': 'RdgButler'}
# {'username': 'uziihashmi_'}
# {'username': 'WhatIsUpAlex'}
# {'username': 'JulesG08'}
# {'username': 'achimdittler'}
# {'username': 'wantactionnow'}
# {'username': 'OluwaGodson3'}
# {'username': 'Sarf_London'}
# {'username': 'BurgessBoston'}
# {'username': 'pedroblindado'}
# {'username': 'Smali44Ali'}
# {'username': 'clemdelz'}
# {'username': 'Publimetrope'}
# {'username': 'ItsMeMeldie'}
# {'username': 'DanielKrolliko1'}
# {'username': 'lambert_to'}
# {'username': 'BesideHands'}
# {'username': 'Sheba02476620'}
# {'username': 'SMQ1029'}
# {'username': 'livsbuzzkill'}
# {'username': 'g10paixao'}
# {'username': 'PeachyFuxx'}
# {'username': 'ClementAnetor'}
# {'username': 'PolishPriest'}
# {'username': 'MoaserLife'}
# {'username': 'AysLondonPromo3'}
# {'username': 'Tpax_00'}
# {'username': 'Kabelo01902065'}
# {'username': 'coyistorresesp'}
# {'username': 'TransTechSocial'}
# {'username': 'StanTheMan0000'}
# {'username': 'CCHOWW1'}
# {'username': 'dorkingbeauty1'}
# {'username': 'TayyibAbu1'}
# {'username': 'glitchofreality'}
# {'username': 'SPD_Jaeger'}
# {'username': 'glitchofreality'}
# {'username': 'TheMagsterChap'}
# {'username': 'jared81319851'}
# {'username': 'fakesheikh888'}
# {'username': 'Agent99XXX'}
# {'username': '1003bestboy'}
# {'username': 'argyris16'}
# {'username': 'uba57'}
# {'username': 'SteveTottenham'}
# {'username': 'feslipeto'}
# {'username': 'Daisy3218'}
# {'username': 't4mike_berlin'}
# {'username': 'davidone711'}
# {'username': 'dakinihu'}
# {'username': 'marcosmoliveira'}
# {'username': 'ToriesOutForeva'}
# {'username': 'King0zor'}
# {'username': 'PeanutBtrToast'}
# {'username': 'Fangs4Fantasy'}
# {'username': 'amberbigtits0'}
# {'username': 'Serbofilo2018'}
# {'username': 'AlexP_MG'}
# {'username': 'Sebfcb14'}
# {'username': 'GoldenShimmer'}
# {'username': '718Burke'}
# {'username': 'LocutusYou'}
# {'username': 'hwcurious1969'}
# {'username': 'Adeelkh52835970'}
# {'username': 'JohnPow28915735'}
# {'username': 'PMTJames'}
# {'username': 'Your_Guy_Nix'}
# {'username': 'xEzequielcito'}
# {'username': 'zquad28'}
# {'username': 'MaadEkbal'}
# {'username': 'amberbigtits0'}
# {'username': 'user23232303'}
# {'username': 'RootOz71'}
# {'username': 'bvbman09'}
# {'username': 'OnyxCap'}
# {'username': 'paulbyrne103x'}
# {'username': 'RockinKrueger'}
# {'username': 'ShOcKjOcK80'}
# {'username': 'TransTechSocial'}
# {'username': 'Ismailkhandrosh'}
# {'username': 'GHAZALFAISAL7'}
# {'username': 'amberbigtits0'}
# {'username': 'delgueg'}
# {'username': 'FAISALNAUMANBU1'}
# {'username': 'ringringdenim'}
# {'username': 'ChicagoTVGuides'}
# {'username': 'nichtJoel'}
# {'username': 'ZazzyJets'}
# {'username': 'keawijkstra'}
# {'username': 'Iivirodrigo'}
# {'username': 'AzamAli11968091'}
# {'username': 'Gingerted1'}
# {'username': 'carlbirch911'}
# {'username': 'alshadowdancer'}
# {'username': 'osamacheema47'}
# {'username': 'senorborges'}
# {'username': 'Nova_NYJ'}
# {'username': 'Reginafrm305'}
# {'username': 'paulabmoore'}
# {'username': 'Hackthegoat'}
# {'username': 'LilibethCedeo20'}
# {'username': 'malatesting'}
# {'username': 'AMV_TV'}
# {'username': 'D51262137'}
# {'username': 'DrTSquare'}
# {'username': 'europea06902978'}
# {'username': 'JorkenGdl'}
# {'username': 'MarkLeesey'}
# {'username': 'StanTheMan0000'}
# {'username': 'greenkeepergav'}
# {'username': 'tufailmohmand1'}
# {'username': 'PowerOfDarkn3ss'}
# {'username': 'ChiChubDaddy'}
# {'username': 'Rakeeb121'}
# {'username': 'SyedTanveer5551'}
# {'username': 'tiiitiiinx'}
# {'username': 'SidZCat'}
# {'username': 'JohnColl84'}
# {'username': 'BradleyBrands'}
# {'username': 'khattakasim380'}
# {'username': 'WCshows23'}
# {'username': 'Zippo3500'}
# {'username': 'jingo_strange'}
# {'username': 'ChiCityRose1'}
# {'username': 'brombelbeer1'}
# {'username': 'NoIAmTonyGreen'}
# {'username': 'career_vault'}
# {'username': 'amberbigtits0'}
# {'username': 'nick215_Camera'}
# {'username': 'Save0urInternet'}
# {'username': 'oliverbeige'}
# {'username': 'talatkaz'}
# {'username': 'alosiomendes'}
# {'username': 'MenInBoxes'}
# {'username': 'MatthewACherry'}
# {'username': 'NataschaBan'}
# {'username': 'Happy_Hussar2'}
# {'username': 'xDixieman'}
# {'username': 'Iivirodrigo'}
# {'username': 'Lourdes21094367'}
# {'username': 'RWarren1966'}
# {'username': 'fannyt1400'}
# {'username': 'Tarpy21'}
# {'username': 'madprouwuxd'}
# {'username': 'Exatheistus'}
# {'username': 'footybrainfood'}
# {'username': 'MarkBeresford11'}
# {'username': 'khaliphaSani'}
# {'username': 'jamjar1970'}
# {'username': 'Missy2Hot'}
# {'username': 'BurkJustinburk'}
# {'username': 'ESGESG1001'}
# {'username': 'kath_trout'}
# {'username': 'whilson_douglas'}
# {'username': 'videocreator16'}
# {'username': 'coyistorresesp'}
# {'username': 'afifa__malik'}
# {'username': 'Kelrod40My'}
# {'username': 'VAMPIRICB0DY'}
# {'username': 'ThirdSoldierr'}
# {'username': 'PamelaJ97523599'}
# {'username': 'nero__127'}
# {'username': 'KierseyDaniel'}
# {'username': 'benrol61'}
# {'username': 'JoeKing1234677'}
# {'username': 'Cassi_Gonzalez_'}
# {'username': 'MadPigFilms'}
# {'username': 'SKECH185'}
# {'username': 'LeeWest00172877'}
# {'username': 'lukebryan1099'}
# {'username': 'The_Walking_Jed'}
# {'username': 'BarnetPost'}
# {'username': 'stuuk1brum'}
# {'username': 'chicagomistress'}
# {'username': 'Shellie18516692'}
# {'username': 'huuge88'}
# {'username': 'callum90CPFC'}
# {'username': 'shigan_shinaa'}
# {'username': 'career_vault'}
# {'username': 'T0k3nWhiTeBoY79'}
# {'username': 'Yasir99803930'}
# {'username': 'ScottEm777'}
# {'username': 'BraveheartRts'}
# {'username': 'peterchristos'}
# {'username': 'athernadeem1431'}
# {'username': 'OlafusiBrieff'}
# {'username': 'lele670'}
# {'username': 'ho96908178'}
# {'username': 'Rock84355505'}
# {'username': 'StanTheMan0000'}
# {'username': 'gabrkas'}
# {'username': 'ResignDonald'}
# {'username': 'lukebryan1099'}
# {'username': 'ashchappo8'}
# {'username': 'KhyreePoole'}
# {'username': 'mcnees'}
# {'username': 'DrDaveOBrien'}
# {'username': 'itsjustmeATL'}
# {'username': 'nyawizzy'}
# {'username': 'asylumudblood'}
# {'username': 'webbywestham14'}
# {'username': 'Handsom33532264'}
# {'username': '24Gabe'}
# {'username': 'thingsilike1982'}
# {'username': 'Holli56548394'}
# {'username': 'Sydenhamphotos'}
# {'username': 'Fkaflipflops'}
# {'username': 'ltsnfIwr'}
# {'username': 'Laughingdog13'}
# {'username': 'koelnsued'}
# {'username': 'boatwr'}
# {'username': 'ninjakick23'}
# {'username': 'Farhakh8'}
# {'username': 'Artie5mith'}
# {'username': 'kate668545441'}
# {'username': 'Candi86947707'}
# {'username': 'NajmiSeher'}
# {'username': 'sughra_abid'}
# {'username': 'JMR8675309'}
# {'username': 'Zaharad52771439'}
# {'username': 'KS20382013'}
# {'username': 'Nietoadrianb'}
# {'username': 'GrahamAntipodes'}
# {'username': 'MunirGrewal1'}
# {'username': 'PabloP_2017'}
# {'username': 'crystalclefairy'}
# {'username': 'SunRayCats'}
# {'username': 'fivaini'}
# {'username': 'InnoArif'}
# {'username': 'jrichardoneill'}
# {'username': 'JackalineMadden'}
# {'username': 'ofc_1892'}
# {'username': 'gregoryemma123'}
# {'username': 'arichmondScot'}
# {'username': 'ani7141'}
# {'username': 'xSmashable'}
# {'username': 'SandraMcMaster1'}
# {'username': 'bobjmsn'}
# {'username': 'The_Sockbacca'}
# {'username': 'BayernfcBoy'}
# {'username': 'jamLx1'}
# {'username': 'Chin87220275'}
# {'username': 'MacDermottGrant'}
# {'username': 'christianiggi'}
# {'username': 'jv_allamerican'}
# {'username': 'FSlycanyon'}
# {'username': 'Rakhisi37666317'}
# {'username': 'Symawah'}
# {'username': 'ReachApparels'}
# {'username': 'yucel_sahinler'}
# {'username': 'Observator_TV'}
# {'username': 'vgcrxexw'}
# {'username': 'Graywol23939115'}
# {'username': 'afcxalbon'}
# {'username': 'BillBolte2'}
# {'username': 'Mahsa14010625'}
# {'username': 'KSP_Libs'}
# {'username': 'austenite_m'}
# {'username': 'Martha_644'}
# {'username': 'BriannaTnt'}
# {'username': 'Michael47646861'}
# {'username': 'VicMcGolden'}
# {'username': 'aarondoc971'}
# {'username': 'John86599827'}
# {'username': 'vivere_liberi'}
# {'username': 'AngelaW70903357'}
# {'username': 'Arabmonie10'}
# {'username': '_Nupz_'}
# {'username': 'torchhorse'}
# {'username': 'ErodingStone'}
# {'username': 'romaingiergen'}
# {'username': 'NaMheesometimes'}
# {'username': 'Nightly_Kay'}
# {'username': 'Pudge_R_Media'}
# {'username': 'Abhijit59205990'}
# {'username': 'Schusti5'}
# {'username': 'Tpsmyth01'}
# {'username': 'Raiven10636297'}
# {'username': 'kalxplaylist'}
# {'username': 'TableTalk101TV'}
# {'username': 'KyleSTaylor27'}
# {'username': 'VABlueBelle18'}
# {'username': 'Dhitzyforero'}
# {'username': 'waikato'}
# {'username': 'AyeBeezy63'}
# {'username': 'Spyder_Webb'}
# {'username': 'taniaghunt'}
# {'username': 'SawyerPetrick'}
# {'username': 'rajputfr17'}
# {'username': 'Br33zy_01'}
# {'username': 'BloggedByRain'}
# {'username': 'TrishHepworth'}
# {'username': 'EricOchotnicki'}
# {'username': 'helmut_dietrich'}
# {'username': 'ILoveKaskade'}
# {'username': 'Winc_King'}
# {'username': 'DrYasmeenUsman'}
# {'username': 'roselau84569622'}
# {'username': 'eyehearshapes'}
# {'username': 'tancred1096'}
# {'username': 'berlin_radler'}
# {'username': 'NicBodifordNFL'}
# {'username': 't88415213'}
# {'username': 'PXtinxion'}
# {'username': 'ValMarshall'}
# {'username': 'michaelc1961'}
# {'username': 'PHICTARD'}
# {'username': 'HaroonRKiyani'}
# {'username': 'talatkaz'}
# {'username': '_Traviata'}
# {'username': 'BayernfcBoy'}
# {'username': 'SCMitchP'}
# {'username': 'Lane59303397'}
# {'username': 'sallyforever14'}
# {'username': 'tschroeder1975'}
# {'username': 'gr3mlyn'}
# {'username': 'JJGreer4'}
# {'username': 'achimdittler'}
# {'username': 'Yun6_Sn0'}
# {'username': 'IramGhumman'}
# {'username': 'cabral_iv'}
# {'username': 'dawg22_j'}
# {'username': 'ArtistasZona'}
# {'username': 'slinforth'}
# {'username': 'uba57'}
# {'username': 'xhassanv'}
# {'username': 'BradfatherSpeak'}
# {'username': 'Amelia_Robert_'}
# {'username': 'Clear_Robot'}
# {'username': 'therealdre_jack'}
# {'username': 'jeremiahakins2'}
# {'username': 'ashandthenfl'}
# {'username': 'NeoInformes'}
# {'username': 'MariaCheema00'}
# {'username': 'jared81319851'}
# {'username': 'MattShelton3'}
# {'username': 'chriss17031'}
# {'username': 'RobertG84477082'}
# {'username': 'AndyP196t1'}
# {'username': 'BearFan920'}
# {'username': 'WhiskyManc'}
# {'username': '_Mauriciorib'}
# {'username': 'llamm888'}
# {'username': 'onespecialmen'}
# {'username': 'SidZCat'}
# {'username': 'Kyron_Carlson96'}
# {'username': 'DicksonMuli_001'}
# {'username': 'JMJ99897378'}
# {'username': 'tori_mcelhaney'}
# {'username': 'NEWONTHEINSIDE'}
# {'username': 'bonnyfechter'}
# {'username': 'Artie5mith'}
# {'username': 'pauldambra'}
# {'username': 'MOberseeschule'}
# {'username': 'ChiChubDaddy'}
# {'username': 'mobfreshsupply'}
# {'username': 'jethrodisney80'}
# {'username': 'LAKERSRISE'}
# {'username': 'VitratG'}
# {'username': 'Tyler_R_Rich'}
# {'username': 'micstavrinides'}
# {'username': 'LadyOfLostSouls'}
# {'username': 'darren_davis_'}
# {'username': 'dario74x'}
# {'username': 'heirhill'}
# {'username': 'vagwitch1'}
# {'username': 'mansa_ra3x'}
# {'username': 'YusterLaiton'}
# {'username': 'MuhamnadIrfan29'}
# {'username': 'Asima33705120'}
# {'username': 'hubita65'}
# {'username': 'FiltheRecords'}
# {'username': 'Chikohora3'}
# {'username': 'kotaphobie'}
# {'username': 'TNeezha'}
# {'username': 'JoHNDoeReturn1'}
# {'username': 'Nav_A1218'}
# {'username': 'VijjiVadapalli'}
# {'username': 'Peterinexile'}
# {'username': 'embedded_iot'}
# {'username': 'TheSingerSmiles'}
# {'username': 'MrSquishums'}
# {'username': 'Hec718'}
# {'username': 'MyLaneguage'}
# {'username': 'Amanda61252392'}
# {'username': 'IsmaeelDar'}
# {'username': 'jenvan16'}
# {'username': 'LosTheIVth'}
# {'username': 'Alexand14627683'}
# {'username': 'ShortbreadFairy'}
# {'username': 'GOWBladeOfChaos'}
# {'username': 'Sydenhamphotos'}
# {'username': 'Muscadaisy'}
# {'username': 'D_Fabulouslife'}
# {'username': 'NeilRos93033708'}
# {'username': 'WorlldG'}
# {'username': 'LandoBeats'}
# {'username': 'Nasiradv7'}
# {'username': 'silviamaresca'}
# {'username': 'proudarcher007'}
# {'username': 'yves_venedey'}
# {'username': 'JosePesce1'}
# {'username': 'CollectorWriter'}
# {'username': 'Manuelq2016'}
# {'username': 'DoWhatUWant66'}
# {'username': 'ryan_sikes10'}
# {'username': 'tomdanza14'}
# {'username': 'Sydney_Arya'}
# {'username': 'diegomarangoni'}
# {'username': 'coldfIowers'}
# {'username': 'dblack665'}
# {'username': 'taylortwilliams'}
# {'username': 'rohithiware'}
# {'username': 'BRD_Satire'}
# {'username': 'MsAnnaSmyth'}
# {'username': 'BaerWisdom'}
# {'username': 'JuliaxMolin'}
# {'username': 'oreos2002'}
# {'username': 'Ruslanoman'}
# {'username': 'GregTakacs'}
# {'username': 'GabrielGTZ'}
# {'username': 'BluePhoenix167'}
# {'username': 'catearthjustice'}
# {'username': 'emiliefantuz'}
# {'username': 'jojoironbow'}
# {'username': 'mackenzie_lemon'}
# {'username': 'dgs_dubbnasty12'}
# {'username': 'Lesli91504880'}
# {'username': 'joeoutlaw6'}
# {'username': 'lynnmariecunli1'}
# {'username': 'BushraAslamm'}
# {'username': 'FeelElectron'}
# {'username': 'Sebastian_hurra'}
# {'username': 'Giulss_93'}
# {'username': 'MrOkoro_1'}
# {'username': 'Ayman_Hrn'}
# {'username': 'LavelleGerald'}
# {'username': 'ParaguayResists'}
# {'username': 'mikethered77'}
# {'username': 'yoavweis'}
# {'username': 'malik_ijaaz'}
# {'username': 'el_ratcliffe'}
# {'username': 'Moskalyk'}
# {'username': 'CandeNaza98'}
# {'username': 'BarnetPost'}
# {'username': 'scrawlzy'}
# {'username': 'afgmeh'}
# {'username': 'GaryHughes2242'}
# {'username': 'azadkastro'}
# {'username': 'delta_sauce'}
# {'username': 'bam57581565'}
# {'username': 'BarryPixel2chop'}
# {'username': 'HParf'}
# {'username': 'AdilQur27207167'}
# {'username': 'sanaTariquk'}
# {'username': 'amitsohal81'}
# {'username': 'TejasZende'}
# {'username': 'voeshii'}
# {'username': 'nkansah_shege'}
# {'username': 'Morales26631153'}
# {'username': 'Djarmstead22'}
# {'username': 'heyricharnold'}
# {'username': 'jg2288'}
# {'username': 'xinvisiblefire'}
# {'username': 'Farhanjaved01'}
# {'username': 'vitusralf'}
# {'username': 'Henri218201'}
# {'username': 'Abdulla01869952'}
# {'username': 'jogintheJsquiet'}
# {'username': 'therealdre_jack'}
# {'username': 'emilylouisej'}
# {'username': 'very_bagel'}
# {'username': 'mondmuesli'}
# {'username': 'ringringdenim'}
# {'username': 'ashslayy_xo22'}
# {'username': 'DingarShubham'}
# {'username': 'tx_ex89'}
# {'username': 'Nadeem88510113'}
# {'username': 'oldscientist'}
# {'username': 'BORNSTUNAS'}
# {'username': 'CooperGoede'}
# {'username': 'zaroni_maria'}
# {'username': 'Gadflyopinion'}
# {'username': 'amberbigtits0'}
# {'username': 'dstone9798'}
# {'username': 'AngelaW70903357'}
# {'username': 'Isi50647322'}
# {'username': 'KhayaDaHome'}
# {'username': 'scrawlzy'}
# {'username': 'BPete1970'}
# {'username': 'usasharenews'}
# {'username': 'SbSadat'}
# {'username': 'raulnewlife'}
# {'username': 'DavidWe16427422'}
# {'username': 'embedded_iot'}
# {'username': 'Etha11907985'}
# {'username': 'AysLondonPromo3'}
# {'username': 'ashleygoon0927'}
# {'username': 'amberbigtits0'}
# {'username': 'QaisarZ21756597'}
# {'username': 'DwhitetheGamer'}
# {'username': '_BB_RADIO_MUSIC'}
# {'username': 'delta_sauce'}
# {'username': 'KidIce9000'}
# {'username': 'PXtinxion'}
# {'username': 'rossstirling83'}
# {'username': 'huuge88'}
# {'username': 'ak8639649'}
# {'username': 'prodbydanny6'}
# {'username': '91_engrusman'}
# {'username': 'juzinhapacotz'}
# {'username': 'Selina_Berlin'}
# {'username': 'ChiBluesHistory'}
# {'username': 'Who2Pitts'}
# {'username': 'qwesi_burga'}
# {'username': 'bilalakhtar00'}
# {'username': 'Mistress_Locke'}
# {'username': 'tavonia28'}
# {'username': 'BlueSyndicalist'}
# {'username': 'freiburgermax'}
# {'username': 'FoDWFiG'}
# {'username': 'syd_niedermeyer'}
# {'username': 'isi_peazy'}
# {'username': 'VickiMo08056436'}
# {'username': 'dugofficial'}
# {'username': 'EmmiHashmi786'}
# {'username': 'MisterFAJ'}
# {'username': 'MRPK24'}
# {'username': 'spreejobs1'}
# {'username': 'iotdir6'}
# {'username': 'Pawe29092439'}
# {'username': 'KeyonBonner4'}
# {'username': 'AnticlockwiseT'}
# {'username': 'interszansa'}
# {'username': 'eeb____'}
# {'username': 'NJanagill'}
# {'username': 'OngoDaArtMan'}
# {'username': 'Sinisterx007'}
# {'username': 'BrandonLHardin'}
# {'username': 'Hawkerflyer'}
# {'username': 'MJFinleyMW'}
# {'username': 'NFL_Covers'}
# {'username': 'radiodotsydney'}
# {'username': 'MariaLovelondon'}
# {'username': 'TheBelleDame1'}
# {'username': 'RobertPHester1'}
# {'username': 'sspdw'}
# {'username': 'buktu_2022'}
# {'username': 'Vorname0Ziffern'}
# {'username': 'wintrypg'}
# {'username': 'Muhamma74830450'}
# {'username': 'Glorfindel1951'}
# {'username': 'eliseNObOdyPlay'}
# {'username': 'oneofmoo'}
# {'username': 'high0boy'}
# {'username': 'RockyRaymon'}
# {'username': 'RachaelBigger'}
# {'username': 'mian_sali007'}
# {'username': 'KhalidK25860064'}
# {'username': 'pmschocolate'}
# {'username': 'J_R_Doom'}
# {'username': 'DevilPedro40'}
# {'username': 'CelesteGrindle6'}
# {'username': 'ArsenalFC_fl'}
# {'username': 'gloangielina'}
# {'username': 'qasimkh51588622'}
# {'username': 'fucktristan'}
# {'username': 'Neshanic99'}
# {'username': 'wormdevil'}
# {'username': 'Uniformguy620'}
# {'username': 'UmberAli9'}
# {'username': 'Pudge_R_Media'}
# {'username': 'MalsDoxy'}
# {'username': 'HashmatMalik13'}
# {'username': 'LisaDonnelly12'}
# {'username': 'bruhbeensolid'}
# {'username': 'gyumlvr'}
# {'username': 'Kh21831223Pti'}
# {'username': 'PaivaAndrews'}
# {'username': 'tknbe'}
# {'username': 'justin_amandro'}
# {'username': 'YsbrydShadow'}
# {'username': 'nazirh2015'}
# {'username': 'Bibi_die_echte'}
# {'username': 'Christi34626895'}
# {'username': 'pykalisto_pasi'}
# {'username': 'Soy_Luchick'}
# {'username': 'lam10112'}
# {'username': '1958_BestYear'}
# {'username': 'NotBadgers'}
# {'username': 'SajdaMughal'}
# {'username': 'IstErnst'}
# {'username': 'elomenelomina'}
# {'username': 'CopleyCapital'}
# {'username': 'NHUB40'}
# {'username': 'Daliboracaoli'}
# {'username': 'mr_quf'}
# {'username': 'Air_3_14'}
# {'username': 'DissidiaDF'}
# {'username': 'Yura61718492'}
# {'username': 'JohnFHennssy'}
# {'username': 'Faizi219'}
# {'username': 'jimsimp98383139'}
# {'username': 'everyholmesbot'}
# {'username': 'enbyiada'}
# {'username': 'vinogps06'}
# {'username': 'ShotByPartznz'}
# {'username': 'Filip35942002'}
# {'username': 'HeartedHooves'}
# {'username': 'BHMBullock'}
# {'username': 'stephenblanchar'}
# {'username': 'Madame_Eule'}
# {'username': 'LilAlisMom'}
# {'username': 'lachdochmal'}
# {'username': 'AasimUsama'}
# {'username': 'amberbigtits0'}
# {'username': 'AdnanAh77393201'}
# {'username': 'marfoster002'}
# {'username': 'B_Sputnik'}
# {'username': 'atthefootofthe1'}
# {'username': 'Radhey58530676'}
# {'username': 'GuibisEvans'}
# {'username': 'charlyokongo'}
# {'username': 'malik_ijaaz'}
# {'username': 'Chris_Vye'}
# {'username': 'Ger_Geraghty'}
# {'username': 'Ja77Punk'}
# {'username': 'LndxNoKamisama'}
# {'username': 'FBIAGENTS3'}
# {'username': 'JuliaTelfer'}
# {'username': 'AysLondonPromo3'}
# {'username': 'zahirhshah'}
# {'username': 'MarkPow65988104'}
# {'username': 'tanis_waggoner'}
# {'username': 'brad_chiro'}
# {'username': 'amberbigtits0'}
# {'username': 'redshirtpride72'}
# {'username': 'Lassharleymari1'}
# {'username': 'MRPK24'}
# {'username': 'austenite_m'}
# {'username': 'yucel_sahinler'}
# {'username': 'Matthewseverns8'}
# {'username': 'zosphotos'}
# {'username': 'HumariaMujahid'}
# {'username': 'grazipinhohotm1'}
# {'username': 'LocutusYou'}
# {'username': 'malatesting'}
# {'username': 'MaureenPickeri5'}
# {'username': 'SoCosTX'}
# {'username': 'andyjcrofts'}
# {'username': 'orlandosports'}
# {'username': 'RobertJ54272519'}
# {'username': 'BillyRa40593679'}
# {'username': '91_engrusman'}
# {'username': 'sinbinnin'}
# {'username': 'Struppilu'}
# {'username': 'ECBRWR'}
# {'username': 'arasasflatout'}
# {'username': 'amberbigtits0'}
# {'username': 'PrimoDaRebel'}
# {'username': 'Frank4630F'}
# {'username': '__YounglG'}
# {'username': 'hatofhijab'}
# {'username': 'zquad28'}
# {'username': 'Ninho227'}
# {'username': 'LBLucky9'}
# {'username': 'KarachiBasi'}
# {'username': 'ringringdenim'}
# {'username': 'absurdistlocker'}
# {'username': 'Diane_Spykens'}
# {'username': 'brvh_yogot'}
# {'username': 'Rishabhh_pandey'}
# {'username': 'Cyril_Matvech'}
# {'username': 'Purp_BlackVeins'}
# {'username': 'WooMySong'}
# {'username': 'AyanAli93403530'}
# {'username': 'NewsPlopcom'}
# {'username': 'lowkeybri333'}
# {'username': 'RobertH03227315'}
# {'username': 'TSoup16'}
# {'username': 'ReachApparels'}
# {'username': 'tahahas96'}
# {'username': 'RaymondTgore'}
# {'username': 'envoyccjun'}
# {'username': 'raulnewlife'}
# {'username': 'ValentinaLux2'}
# {'username': 'DigiTechReviews'}
# {'username': 'William48862798'}
# {'username': 'JenLongdenNews'}
# {'username': 'BadzaVa'}
# {'username': 'QuickCartWP'}
# {'username': 'ValentinaLux2'}
# {'username': 'midland__london'}
# {'username': 'RichardVoce1'}
# {'username': 'PatrioThQmas'}
# {'username': 'rjtweetuk'}
# {'username': 'aripr_'}
# {'username': 'BazarganiShiva'}
# {'username': 'Tazzie10296486'}
# {'username': 'WomenDefendRoj1'}
# {'username': 'jguillaume17'}
# {'username': '_Brett93'}
# {'username': 'TengVang87'}
# {'username': 'CommonPerson50'}
# {'username': 'earlvox'}
# {'username': 'ubathediplomat'}
# {'username': 'BitmaxNazarene'}
# {'username': 'Glorfindel1951'}
# {'username': 'Cosima_98'}
# {'username': 'MatthewParsona1'}
# {'username': 'umm_e_umer4'}
# {'username': 'Optimusbl'}
# {'username': 'khan_memet'}
# {'username': 'stevepernicone'}
# {'username': 'Coolhand6661'}
# {'username': 'VincentVega1906'}
# {'username': 'DStikovec'}
# {'username': 'RockyHendrick2'}
# {'username': 'BuddyGumbo'}
# {'username': 'flicksfan'}
# {'username': 'AngelaCoast1'}
# {'username': 'BonnieS04304237'}
# {'username': 'HairyMonkeyGor1'}
# {'username': 'RafeaAhmed4'}
# {'username': 'bilaj35'}
# {'username': 'SethNketiah1'}
# {'username': 'AKlarchen'}
# {'username': 'aic_architect'}
# {'username': 'Lucy_in_Bungay'}
# {'username': 'REICollege'}
# {'username': 'EvChapo'}
# {'username': '0000004041203e'}
# {'username': 'REICollege'}
# {'username': 'andykn101'}
# {'username': 'M4DELA1NE'}
# {'username': 'broncovike'}
# {'username': 'Callicleez'}
# {'username': 'ZeBi35'}
# {'username': 'BlizzyB_'}
# {'username': 'bluestar121797'}
# {'username': 'REICollege'}
# {'username': 'pis_u'}
# {'username': 'hotandhorny1169'}
# {'username': 'leobardotorr'}
# {'username': 'mandoluvbot'}
# {'username': 'DoWhatUWant66'}
# {'username': 'ZachOsip'}
# {'username': 'GrahamC15285923'}
# {'username': 'Jacek2022'}
# {'username': 'Sydney_Screams'}
# {'username': 'Firstsinister'}
# {'username': 'JakeStrimbu'}
# {'username': 'Geolarker'}
# {'username': 'BecomingBrandon'}
# {'username': 'jqmdaf'}
# {'username': 'khan_memet'}
# {'username': 'austenite_m'}
# {'username': 'dolly_suke'}
# {'username': 'thecluelesschic'}
# {'username': 'faimillishit'}
# {'username': 'leslie_garin'}
# {'username': 'cocuyoroyo'}
# {'username': 'CarolMa26353464'}
# {'username': 'justinb89097936'}
# {'username': 'JosephQuinnUK'}
# {'username': 'sitedataseo'}
# {'username': 'catseyesjohnson'}
# {'username': 'AysLondonPromo3'}
# {'username': 'rothpaul17'}
# {'username': 'andremtl123'}
# {'username': 'Cosima_98'}
# {'username': 'usasharenews'}
# {'username': '7_ja_'}
# {'username': 'wherescourtney'}
# {'username': 'greydornan05'}
# {'username': 'Ciratyiana'}
# {'username': 'ColeRobbieBeats'}
# {'username': 'abdalahsaidi12'}
# {'username': 'Pamp'}
# {'username': 'paulerockalot'}
# {'username': 'IanSeward'}
# {'username': 'CarasikS'}
# {'username': 'KayceeKiligan'}
# {'username': 'd_kalis1'}
# {'username': 'tinataylor1019'}
# {'username': 'mmctec'}
# {'username': 'AysLondonPromo3'}
# {'username': 'd_kalis1'}
# {'username': 'ChiraqSoldiers'}
# {'username': 'MitchellS4464'}
# {'username': '_literatureco'}
# {'username': 'wooriyouni'}
# {'username': 'TheStocksStudio'}
# {'username': 'nytemarezxz'}
# {'username': 'kmealow3217'}
# {'username': 'Scaryboab1'}
# {'username': 'Trudilu'}
# {'username': 'GodMasih'}
# {'username': 'MacinnisVal'}
# {'username': 'AysLondonPromo3'}
# {'username': 'NataliaSoshko'}
# {'username': 'ADUSEISTERLLLIN'}
# {'username': 'lm_nash123'}
# {'username': 'KokaiShin'}
# {'username': 'nicholas_cussen'}
# {'username': 'otmmlw'}
# {'username': 'yommy_presh'}
# {'username': 'Khalidihsan7786'}
# {'username': 'Rinuuu1'}
# {'username': 'drimran87'}
# {'username': 'Yolande83366723'}
# {'username': 'Hotwielzz'}
# {'username': '02031961pat'}
# {'username': 'fratbyhlt'}
# {'username': 'Trulyoftheyard'}
# {'username': 'Selma48426844'}
# {'username': 'xanthippe39'}
# {'username': 'MMontgomery19'}
# {'username': 'ivan_wathum'}
# {'username': 'RSSFeedsCloud'}
# {'username': 'dngdgfxxa344'}
# {'username': 'Zaheer89049351'}
# {'username': 'lngobernabIe_'}
# {'username': 'JamesRo16814709'}
# {'username': 'GuthierRainer'}
# {'username': 'blogfrey'}
# {'username': 'sergiosczl'}
# {'username': 'awwalker24'}
# {'username': '_vivianvee'}
# {'username': 'GregReinhart'}
# {'username': 'lostflood'}
# {'username': 'Mililicoo'}
# {'username': 'Elijahfuckoff'}
# KeyboardInterrupt
